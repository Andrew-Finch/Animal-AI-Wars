# %%
import json
import pandas as pd

test = {
    "<STAGE_ID_1>": {
        "id": "<STAGE_ID_1>",
        "title": "<TITLE OF STAGE 1>",
        "description": "<DESCRIPTION OF TASK 1>"
    },
    "<STAGE_ID_2>": {
        "id": "<STAGE_ID_2>",
        "title": "<TITLE OF STAGE 2>",
        "description": "<DESCRIPTION OF TASK 2>"
    },
    "<STAGE_ID_3>": {
        "id": "<STAGE_ID_3>",
        "title": "<TITLE OF STAGE 3>",
        "description": "<DESCRIPTION OF TASK 3>"
    }
}

test = { 
    "1": { "id": "1", "title": "Order Captured", "description": "Order information entered by the user into the webpage, followed by input checks, and inventory check." }, 
    "2": { "id": "2", "title": "Shopping Cart", "description": "User adds the order to the cart, updating the shopping cart." }, 
    "3": { "id": "3", "title": "Offers", "description": "Promotional offers are identified and provided. Users can accept or decline the offers." }, 
    "4": { "id": "4", "title": "Checkout Process", "description": "User selects checkout, enters the address, and mailing and shipping details are provided." }, 
    "5": { "id": "5", "title": "Payment Processing", "description": "Payment is processed upon update of inventory." }, 
    "6": { "id": "6", "title": "Order Fulfillment", "description": "Order is fulfilled by the warehouse after notification." } 
}

df_dict = {"id" : [], "title" : [], "description" : []}

for item in test:
    df_dict['id'].append(test[item]['id'])
    df_dict['title'].append(test[item]['title'])
    df_dict['description'].append(test[item]['description'])

df_dict
# data = json.loads(test)
# # Convert JSON data to a DataFrame
df = pd.DataFrame(df_dict)
# Display data as a table in Streamlit
df
# Out:
#   id               title                                        description
# 0  1      Order Captured  Order information entered by the user into the...
# 1  2       Shopping Cart  User adds the order to the cart, updating the ...
# 2  3              Offers  Promotional offers are identified and provided...
# 3  4    Checkout Process  User selects checkout, enters the address, and...
# 4  5  Payment Processing     Payment is processed upon update of inventory.
# 5  6   Order Fulfillment  Order is fulfilled by the warehouse after noti...

# %%
import base64
import requests
import os
from PIL import Image
import io
from openai import OpenAI
from dotenv import load_dotenv 

load_dotenv()

client = OpenAI()

api_key = "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"

def compare_image_url_prompt(as_json: bool, image_urls: list, prompt_text: str, model: str = "gpt-4o", max_tokens: int = 1500) -> str:

    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {api_key}"
    }

    content = [{"type": "text","text": prompt_text}]

    for url in image_urls:
        content.append({"type": "image_url","image_url": {"url": f"{url}"}})

    payload = {
        "model": model,
        "messages": [
            {
                "role": "user",
                "content":content
            }
        ],
        "max_tokens": max_tokens
    }

    if as_json:
        payload["response_format"] = {"type": "json_object"}
    response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

    return response

urls = [
    "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg",
    "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"
]

test = compare_image_url_prompt(False, urls, "Is there a difference between these two images?")

print(test.text)
# Out:
# {
#   "id": "chatcmpl-9Ux6PZSTBm10VxJFkkP8fK9uvpNFf",
#   "object": "chat.completion",
#   "created": 1717164057,
#   "model": "gpt-4o-2024-05-13",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "There is no discernible difference between the two images you provided. They appear to be identical, each showing a wooden path leading through a green field under a partly cloudy sky."
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 2226,
#     "completion_tokens": 35,
#     "total_tokens": 2261
#   },
#   "system_fingerprint": "fp_aa87380ac5"
# }
